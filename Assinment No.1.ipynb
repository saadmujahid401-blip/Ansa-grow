# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
# Write your code here
first_name="saad"
last_name="mujahid"

full_name = first_name + last_name

full_name.upper()
# Out:
# 'SAADMUJAHID'

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
# Write your code here
fruit = input("Apna favourite fruit ka naam batae?")
print("Ap ke favourite fruit ke naam me",len(fruit),"characters hain.")
# Out:
# Apna favourite fruit ka naam batae? Banana
# Ap ke favourite fruit ke naam me 6 characters hain.

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
# Write your code here
sentence = ("python is fun")
new_sentence = sentence.replace("fun","awesome")
print(new_sentence)
# Out:
# python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
# Write your code here
text = "HELLO WORLD"
index = text.find("WORLD")
print("world ka start index hai",index)
# Out:
# world ka start index hai 6

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
# Write your code here
email = input("Apna email address kya he:")
email_lower = email.lower()
print("lowercase email:",email_lower)
# Out:
# Apna email address kya he: SAREEMRAZA475@GMAIL.COM
# lowercase email: sareemraza475@gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
# Write your code here
sentence = "     python programming     "
clean_sentence = sentence.strip()
print(clean_sentence)
# Out:
# python programming

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
# Write your code here
text = "welcome to coding"
count_o = text.count("o")
print("letter o kitni baar aya he:",count_o)
# Out:
# letter o kitni baar aya he: 3

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
# Write your code here
age = input("Apni age bataein:")
age_int = int(age)
print("apki age he:" , age_int)
# Out:
# Apni age bataein: 25
# apki age he: 25

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
# Write your code here
value = 15.99
converted = int(value)
print(converted)
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
# Write your code here
num1 = input("first number he:")
num2 = input("second number he:")
sum_num = int(num1)+int(num2)
print("total number is:",sum_num)
# Out:
# first number he: 35
# second number he: 27
# total number is: 62

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
# Write your code here
num = 100
num_str = str(num)
print(type(num_str))
# Out:
# <class 'str'>

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
# Write your code here
price = input("price dalein:")
price_int = int(float(price))
print("Apka price he:",price_int)
# Out:
# price dalein: 57.4
# Apka price he: 57

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
# Write your code here
a= "10"
b= "20"
result = int(a) + int(b)
print("Apka result he:",result)
# Out:
# Apka result he: 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
# Write your code here
value = "50.5"
result= float(value)+10
print(result)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
# Write your code here
name = input("apka naam kya he?")
city = input("Ap ka sheher ka naam ?")
print("Hello", name +",welcome to" ,city)
# Out:
# apka naam kya he? RAZEEM
# Ap ka sheher ka naam ? Faridabad
# Hello RAZEEM,welcome to Faridabad

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
# Write your code here
num1= input("first number:")
num2= input("second number:")
product_num= int(num1) * int(num2)
print("the result is :",product_num)
# Out:
# first number: 45
# second number: 3
# the result is : 135

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
# Write your code here
color= input("what is your favorite color:")
print("I also like",color)
# Out:
# what is your favorite color: blue
# I also like blue

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
# Write your code here
birth_year = input("Apki birth year kya he:")
current_year = 2026
current_age = current_year - int(birth_year)
print("Apki current age he",current_age)
# Out:
# Apki birth year kya he: 2002
# Apki current age he 24

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
# Write your code here
word = input("ek word likhe")
print(word * 5)
# Out:
# ek word likhe lawaris
# lawarislawarislawarislawarislawaris

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
# Write your code here
number = input("Apna mobile number bataein:")
print("Apka ye number he ",number)
# Out:
# Apna mobile number bataein: 035637327433
# Apka ye number he  035637327433

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
# Write your code here
a=10
b=3
remainder = a % b
print("reminder hai:",remainder)
# Out:
# reminder hai: 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
# Write your code here
result = 15>20 and 10<20
print(result)
# Out:
# False

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
# Write your code here
num = input("type a number:")
num_check = int(num) 
print(num_check > 100)
# Out:
# type a number: 134
# True

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
# Write your code here
result = (2**5)
print(result)
# Out:
# 32

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
# Write your code here
result = 50 == 100
print(result)
# Out:
# False

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
# Write your code here
a = True
b = False

result = a or b

print(result)
# Out:
# True

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
# Write your code here
num = int(input("enter a number:"))
if num>0:
    print("number positive he.")
elif num<0:
    print("number negative he.")
else:
    print("number is zero")
# Out:
# enter a number: 3
# number positive he.

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
# Write your code here
age = int(input("Enter your age"))
if age>18:
    print("eligible for vote")
else:
    print("not eligible for vote")
# Out:
# Enter your age 16
# not eligible for vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
# Write your code here
num = int(input("enter a number:"))
if num % 2 == 0:
    print("ye even number he")
else:
    print("ye odd number he")
# Out:
# enter a number: 8
# ye even number he

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
# Write your code here
num1 = int(input("enter first number:"))
num2 = int(input("enter second number:"))

if num1 > num2:
    print("first number badha he")
elif num1 < num2:
    print("second number badha he")
else:
    print("both are equal")
# Out:
# enter first number: 34
# enter second number: 45
# second number badha he

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
# Write your code here
marks = int(input("enter your marks"))
if marks > 33:
    print("pass")
else: 
    print("fail")
# Out:
# enter your marks 45
# pass

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
# Write your code here
text = input("type here:")
if text == "":
 print ("string empty he")
else:
    print("string empty nahi he")
# Out:
# type here: dass
# string empty nahi he

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
# Write your code here
password = input("enter your password")
if password == "python123":
    print ("Access Granted")
else: 
    print ("Wrong password")
# Out:
# enter your password python123
# Access Granted

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
# Write your code here
num = input("enter a number :")
if num == 0 :
 print("number zero hai")
else:
    print ("number zero nahi he")
# Out:
# enter a number : 8
# number zero nahi he

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
# Write your code here
marks = float(input("Enter marks here:"))
if    marks >=90:
       print("grade:A")
elif  marks >=80:
       print("grade:B")
elif  marks >=70:
       print("grade:C")
else:
    print("grade:D")
# Out:
# Enter marks here: 78
# grade:C

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
# Write your code here
temp = float(input("what is the temperature"))
if temp >=30:
 print("It is hot")
elif temp >=15:
    print("it is warm")
else:
    print ("it is cold")
# Out:
# what is the temperature 34
# It is hot

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
# Write your code here
num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
elif num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")
else:
    print("Not divisible by 3 or 5")
# Out:
# Enter a number:  30
# FizzBuzz

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
# Write your code here
ch = input("character enter karein:")
if  ch == "a,e,i,o,u" :
    print("its vowel")
else:
    print("it is consonant")
# Out:
# character enter karein: d
# it is consonant

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
# Write your code here
# Bill amount input lena
bill = float(input("Apna bill amount likhein: "))

# Discount logic
if bill > 5000:
    discount = bill * 0.20
    print("20% discount apply hua hai:", discount)
elif bill >= 2000:
    discount = bill * 0.10
    print("10% discount apply hua hai:", discount)
else:
    print("No discount")
# Out:
# Apna bill amount likhein:  6000
# 20% discount apply hua hai: 1200.0

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
# Write your code here
age = int(input("Enter your age:"))
if age >=60:
    print ("senior citizen")
elif age >=20:
    print ("Adult")
elif age >=12:
    print ("Teenager")
else:
    print ("child")
# Out:
# Enter your age: 76
# senior citizen

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
# Write your code here

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
# Write your code here
week = int(input("Enter week num (1-7) :"))
if week ==1:
    print("Monday")
elif week ==2:
    print("Tuesday")
elif week ==3:
    print("wendesday")
elif week ==4:
    print("Thursday")
elif week ==5:
    print("friday")
elif week ==6:
    print("saturday")
elif week ==7:
    print("sunday")
else:
    print ("This is not available")
# Out:
# Enter week num (1-7) : 3
# wendesday

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
# Write your code here
num1 = float(input("Enter first number:"))
operator = input("enter an operator:")
num2 = float(input("Enter second number:"))
if operator == "+" :
       print("result:",num1+num2)
elif operator == "-" :
      print ("result:" , num1-num2)
elif operator != "/" :
      print ("result:" , num1/num2)
elif operator == "*" :
      print ("result:" , num1*num2)
else: 
    print("error")
# Out:
# Enter first number: 24
# enter an operator: +
# Enter second number: 2
# result: 26.0

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
# Write your code here
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = weight / (height ** 2)

print("BMI =", bmi)

if bmi < 18.5:
    print("Category: Underweight")
elif bmi < 25:
    print("Category: Normal")
else:
    print("Category: Overweight")
# Out:
# Enter your weight in kg:  56
# Enter your height in meters:  2.3
# BMI = 10.586011342155011
# Category: Underweight

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
# ATM Machine Logic

correct_pin = 2003
balance = 85500

pin = int(input("Enter your PIN: "))

if pin == correct_pin:
    amount = int(input("Enter withdrawal amount: "))
    
    if amount <= balance:
        balance = balance - amount
        print("Withdrawal Success")
        print("Remaining Balance:", balance)
    else:
        print("Insufficient Balance")
        
else:
    print("Incorrect PIN")
# Out:
# Enter your PIN:  2003
# Enter withdrawal amount:  4536
# Withdrawal Success
# Remaining Balance: 80964

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
# Login System

correct_username = "rahat"
correct_password = "root"

username = input("Enter Username: ")

if username == correct_username:
    
    password = input("Enter Password: ")
    
    if password == correct_password:
        print("Login Successful")
    else:
        print("Incorrect Password")

else:
    print("Username not found")
# Out:
# Enter Username:  rahat
# Enter Password:  root
# Login Successful

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
# Write your code here
num1 = int(input("Enter a number:"))
num2 = int(input("Enter a number:"))
num3 = int(input("Enter a number:"))

if num1 > num2:

        if num1 > num3:
            print("largest number is :", num1)
        else: 
            print ("largest number is :",num3)
else:

    if num2 > num3:
        print ("largest number is :",num2)
    else:
        print ("largest number is :",num3)
# Out:
# Enter a number: 23
# Enter a number: 33
# Enter a number: 23
# largest number is : 33

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
# Write your code here
age = int(input("Enter your age"))

if age > 18:
    ID = input("do you have an id:")

    if  ID == "yes":
        print ("Ticket issued")
    else:
        print("ID required")

else:
    print("not allowed")
# Out:
# Enter your age 21
# do you have an id: yes
# Ticket issued

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
# Write your code here
marks = int(input("Enter your marks here:"))

if marks > 80:
    interview = input("interview clear he ya nahi?")

    if interview == "clear hai":
        print ("Admission done")
    else:
        print("Admission cancelled")
else:
    print("interview could not be conducted")
# Out:
# Enter your marks here: 98
# interview clear he ya nahi? nhi
# Admission cancelled

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
# Write your code here
num = int(input("enter a number:"))

if num > 0:

    if num > 100:
        print("number is larger and positive")
    else:
        print ("number is smaller and positive")

else:
 print("number is not positive")
# Out:
# enter a number: 112
# number is larger and positive

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
food_type = input("Enter Veg or Non-Veg: ")

if food_type == "Veg":
    
    veg_item = input("Choose Paneer or Dal: ")
    
    if veg_item == "Paneer":
        print("You ordered Paneer")
    else:
        print("You ordered Dal")

else:
    
    nonveg_item = input("Choose Chicken or Mutton: ")
    
    if nonveg_item == "Chicken":
        print("You ordered Chicken")
    else:
        print("You ordered Mutton")
# Out:
# Enter Veg or Non-Veg:  Non-veg
# Choose Chicken or Mutton:  mutton
# You ordered Mutton

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
# Write your code here
num = int(input("Enter a number:"))

if -9 <= num <= 9:
    print("single digit hai")
elif -99 <= num <= 99:
    print("double digit hai")
elif -999 <= num <=999:
    print("triple digit hai")
else:
    print ("cant answer this ")
# Out:
# Enter a number: 345
# triple digit hai

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
# Write your code here
salary = float(input("Enter your salary :"))
service = int(input("What is your service year:"))

if  service > 5:
    bonus = salary * 0.05
    final_salary = salary + bonus

    print ("bonus",bonus)
    print("salary",salary)

else:
    print ("You aren't provided bonus")
    print ("your salary is",salary)
# Out:
# Enter your salary : 22000
# What is your service year: 6
# bonus 1100.0
# salary 22000.0

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
# Write your code here
side1 = int(input("ENTER THE NUMBER:"))
side2 = int(input("ENTER THE NUMBER:"))
side3 = int(input("ENTER THE NUMBER:"))

if side1 == side2 == side3:
    print("It is an equilateral triangle")
elif side1 == side2 or side1 == side3 or side2 == side3:
    print("It is an isosceles triangle")
else: 
    print("It is an scalene triangle")
# Out:
# ENTER THE NUMBER: 2
# ENTER THE NUMBER: 2
# ENTER THE NUMBER: 2
# It is an equilateral triangle

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
month = input("Month name enter karein: ").lower()

if month == "january" or month == "jan":
    print("January mein 31 days hote hain")
    
elif month == "february" or month == "feb":
    print("February mein 28 ya 29 days hote hain")
    
elif month == "march" or month == "mar":
    print("March mein 31 days hote hain")
    
elif month == "april" or month == "apr":
    print("April mein 30 days hote hain")
    
elif month == "may":
    print("May mein 31 days hote hain")
    
elif month == "june" or month == "jun":
    print("June mein 30 days hote hain")
    
elif month == "july" or month == "jul":
    print("July mein 31 days hote hain")
    
elif month == "august" or month == "aug":
    print("August mein 31 days hote hain")
    
elif month == "september" or month == "sep":
    print("September mein 30 days hote hain")
    
elif month == "october" or month == "oct":
    print("October mein 31 days hote hain")
    
elif month == "november" or month == "nov":
    print("November mein 30 days hote hain")
    
elif month == "december" or month == "dec":
    print("December mein 31 days hote hain")
    
else:
    print("Invalid month name")
# Out:
# Month name enter karein:  may
# May mein 31 days hote hain

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
# Write your code here
num = int(input("Enter a number:"))

if num % 2 == 0:

    if num > 50:
        print ("It is an even and bigger number.")
    else:
        print ("It is an even and smaller number.")

else:
    print("It is an odd number.")
# Out:
# Enter a number: 85
# It is an odd number.

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
# Write your code here
science = float(input("Enter your marks:"))
maths = float(input("enter your marks:"))

if science >= 40 and maths >= 40:
    print ("student is passed")
else:
    print("student is failed")
    if maths < 40:
        print("maths is weak")
    if science < 40:
        print("science is weak")
# Out:
# Enter your marks: 54
# enter your marks: 45
# student is passed

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
# Write your code here
unit = int(input("Enter the units"))
if  unit <=100:
     bill = 0
elif unit <= 200:
    bill =(unit-100) *5
else:
    bill = (100*5) + ((unit-200) * 10)

print("Electricity bill = ",bill)
# Out:
# Enter the units 234
# Electricity bill =  840

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
# Write your code here
score = int(input("enter your game score:"))

if score >= 0 and score <= 50:
    print("Ap beginner level pe ho!")
elif score >= 50 and score <= 100:
    print("Ap intermediatre level pe ho!")

    boss= input("Apne boss clear kiya he ?")
   
    if boss == "yes":
        print("Boss level clewar he.")
    else:
        print("boss level clear nahi he")
else:
    print ("invalid score")
# Out:
# enter your game score: 65
# Ap intermediatre level pe ho!
# Apne boss clear kiya he ? yes
# Boss level clewar he.

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
# Write your code here
username = input("username enter :")
password = input("password enter:")

correct_username = "waraich"
correct_password = "tadde marre"
security_code = "heaven" 

if username == correct_username or password == correct_password:
    print("Login successful")

    attempts = 0
    while attempts < 3:
        code = input("security pupose:apna code dalo").lower

        if code == security_code:
            print ("Access granted....")
           
            break
            
        else:
            print ("ghalat baat")

            attempts += 1
            
        if attempts == 3:
            print("Account temporary lock hogaya he ,thori deir baad koshish kije ga!!")
else:
    print("Invalid username and password")
# Out:
# username enter : waraich
# password enter: tadde marre
# Login successful
# security pupose:apna code dalo heaven
# ghalat baat
# security pupose:apna code dalo heaven
# ghalat baat
# security pupose:apna code dalo heaven
# ghalat baat
# Account temporary lock hogaya he ,thori deir baad koshish kije ga!!
